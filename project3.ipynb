# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('./datasets/kospi사업.csv')
# Out:
#       Unnamed: 0        회사명   거래소코드     회계년도  정상영업이익증가율  순이익증가율    1주당순이익
# 0             12   (주)DB하이텍     990  2007/12       0.00    0.00   -1151.0  \
# 1             13   (주)DB하이텍     990  2008/12       0.00    0.00   -8904.0
# 2             14   (주)DB하이텍     990  2009/12       0.00    0.00   -5481.0
# 3             15   (주)DB하이텍     990  2010/12       0.00    0.00   -5072.0
# 4             16   (주)DB하이텍     990  2011/12       0.00    0.00   -2541.0
# ...          ...        ...     ...      ...        ...     ...       ...
# 2415        2824  효성첨단소재(주)  298050  2022/12     -27.95  -50.00   28053.0
# 2416        2826   효성티앤씨(주)  298020  2019/12     158.22  338.18   21569.0
# 2417        2827   효성티앤씨(주)  298020  2020/12     -17.45   46.96   31698.0
# 2418        2828   효성티앤씨(주)  298020  2021/12     434.08  463.14  178503.0
# 2419        2829   효성티앤씨(주)  298020  2022/12     -91.32  -98.50    2686.0
#
#         부채비율  매출액정상영업이익률  매출액증가율      PER    PBR     PCR
# ...

# %%
pd.read_csv('./datasets/kospi반기.csv')
# Out:
#       Unnamed: 0         회사명   거래소코드     회계년도  정상영업이익증가율   순이익증가율   1주당순이익
# 0              0  (주)BNK금융지주  138930  2011/06        NaN      NaN      NaN  \
# 1              1  (주)BNK금융지주  138930  2012/06        NaN      NaN      NaN
# 2              2  (주)BNK금융지주  138930  2013/06        NaN      NaN      NaN
# 3              3  (주)BNK금융지주  138930  2014/06        NaN      NaN      NaN
# 4              4  (주)BNK금융지주  138930  2015/06        NaN      NaN      NaN
# ...          ...         ...     ...      ...        ...      ...      ...
# 2542        2634    효성티앤씨(주)  298020  2018/06        NaN      NaN      NaN
# 2543        2635    효성티앤씨(주)  298020  2019/06     551.38     0.00  14680.0
# 2544        2636    효성티앤씨(주)  298020  2020/06     -52.21   -89.17   1590.0
# 2545        2637    효성티앤씨(주)  298020  2021/06     801.67  5379.39  87118.0
# 2546        2638    효성티앤씨(주)  298020  2022/06     -56.21   -74.84  21917.0
#
#         부채비율  매출액정상영업이익률  매출액증가율     PER  PBR     PCR
# ...
